# %%
import pandas as pd

# %%
lines_path = "../infra/debug_lines.csv"
paragraphs_path = "../infra/debug_paragraphs.csv"

df_lines = pd.read_csv(lines_path)
df_paragraphs = pd.read_csv(paragraphs_path)
df_lines.columns, df_paragraphs.columns
# Out:
# (Index(['page', 'line_enum', 'text', 'tokens', 'x0', 'y0', 'x1', 'y1', 'width',
#         'height', 'empty_line', 'only_special', 'only_special_len',
#         'text_wo_numbers', 'text_wo_numbers_len', 'text_duplicated',
#         'to_delete_line'],
#        dtype='object'),
#  Index(['page', 'paragraph_enum', 'text', 'clean_text', 'y0', 'x0', 'y1', 'x1',
#         'width', 'height'],
#        dtype='object'))
